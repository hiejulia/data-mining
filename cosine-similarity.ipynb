# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)


# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# RECOMMENDATION ENGINE

# %%
import pandas as pd
import numpy as np
import requests
import json
from sklearn.metrics.pairwise import cosine_similarity
print("ok")
# Out:
# ok

# %%
myun = 'hienminhnguyen717171'
mypw = '5925990e4468e7f5071389d52a90341bcaeab007'

my_starred_repos = []
def get_starred_by_me():
    resp_list = []
    last_resp = ''
    first_url_to_get = 'https://api.github.com/user/starred'
    first_url_resp = requests.get(first_url_to_get, auth=(myun,mypw))
    last_resp = first_url_resp
    resp_list.append(json.loads(first_url_resp.text))
    
    while last_resp.links.get('next'):
        next_url_to_get = last_resp.links['next']['url']
        next_url_resp = requests.get(next_url_to_get, auth=(myun,mypw))
        last_resp = next_url_resp
        resp_list.append(json.loads(next_url_resp.text))
        
    for i in resp_list:
        for j in i:
            msr = j['html_url']
            my_starred_repos.append(msr)

# %%
get_starred_by_me()

# %%
my_starred_repos
# Out:
# ['https://github.com/VastoLorde95/Competitive-Programming',
#  'https://github.com/spring-projects/spring-security-oauth',
#  'https://github.com/prabhupant/python-ds',
#  'https://github.com/azl397985856/leetcode',
#  'https://github.com/iiitv/algos',
#  'https://github.com/bufferapp/README',
#  'https://github.com/apple/swift-protobuf',
#  'https://github.com/springfox/springfox',
#  'https://github.com/jmportilla/Python-for-Algorithms--Data-Structures--and-Interviews',
#  'https://github.com/hussien89aa/DataStructureAndAlgorithms',
#  'https://github.com/vprusso/youtube_tutorials',
#  'https://github.com/checkcheckzz/system-design-interview',
#  'https://github.com/vmironichev/phone-app',
#  'https://github.com/P1xt/google-interview-university',
#  'https://github.com/spring-cloud/spring-cloud-netflix',
#  'https://github.com/labnol/unsubscribe-gmail',
#  'https://github.com/jwasham/coding-interview-university',
#  'https://github.com/halo-dev/halo',
#  'https://github.com/xolstice/protobuf-maven-plugin',
#  'https://github.com/microsoft/azure-spring-boot',
#  'https://github.com/protocolbuffers/protobuf',
#  'https://github.com/Azure/azure-cli',
#  'https://github.com/Azure/azure-powershell',
#  'https://github.com/nicolashery/mac-dev-setup']

# %%
len(my_starred_repos)
# Out:
# 24

# %%
my_starred_users = []
for ln in my_starred_repos:
    right_split = ln.split('.com/')[1]
    starred_usr = right_split.split('/')[0]
    my_starred_users.append(starred_usr)

# %%
my_starred_users
# Out:
# ['VastoLorde95',
#  'spring-projects',
#  'prabhupant',
#  'azl397985856',
#  'iiitv',
#  'bufferapp',
#  'apple',
#  'springfox',
#  'jmportilla',
#  'hussien89aa',
#  'vprusso',
#  'checkcheckzz',
#  'vmironichev',
#  'P1xt',
#  'spring-cloud',
#  'labnol',
#  'jwasham',
#  'halo-dev',
#  'xolstice',
#  'microsoft',
#  'protocolbuffers',
#  'Azure',
#  'Azure',
#  'nicolashery']

# %%
len(my_starred_users)
# Out:
# 24

# %%
len(set(my_starred_users))
# Out:
# 23

# %%
# Get repos they star 
starred_repos = {k:[] for k in set(my_starred_users)}
def get_starred_by_user(user_name):
    starred_resp_list = []
    last_resp = ''
    first_url_to_get = 'https://api.github.com/users/'+ user_name +'/starred'
    first_url_resp = requests.get(first_url_to_get, auth=(myun,mypw))
    last_resp = first_url_resp
    starred_resp_list.append(json.loads(first_url_resp.text))
    
    while last_resp.links.get('next'):
        next_url_to_get = last_resp.links['next']['url']
        next_url_resp = requests.get(next_url_to_get, auth=(myun,mypw))
        last_resp = next_url_resp
        starred_resp_list.append(json.loads(next_url_resp.text))
        
    for i in starred_resp_list:
        for j in i:
            sr = j['html_url']
            starred_repos.get(user_name).append(sr)

# %%
for usr in list(set(my_starred_users)):
    print(usr)
    try:
        get_starred_by_user(usr)
    except:
        print('failed for user', usr)
# Out:
# prabhupant
# jwasham
# spring-projects
# P1xt
# hussien89aa
# microsoft
# jmportilla
# Azure
# bufferapp
# apple
# VastoLorde95
# vmironichev
# spring-cloud
# azl397985856
# vprusso
# springfox
# labnol
# nicolashery
# halo-dev
# checkcheckzz
# iiitv
# xolstice
# protocolbuffers

# %%
len(starred_repos)
# Out:
# 23

# %%
# All repos star by users I star 

repo_vocab = [item for sl in list(starred_repos.values()) for item in sl]

repo_set = list(set(repo_vocab))

len(repo_set)
# Out:
# 3055

# %%
all_usr_vector = []
for k,v in starred_repos.items():
    usr_vector = []
    for url in repo_set:
        if url in v:
            usr_vector.extend([1])
        else:
            usr_vector.extend([0])
    all_usr_vector.append(usr_vector)

# %%
len(all_usr_vector)
# Out:
# 23

# %%
df = pd.DataFrame(all_usr_vector, columns=repo_set, index=starred_repos.keys())
df
# Out:
#                  https://github.com/bfirsh/jsnes  ...  https://github.com/databricks/scala-style-guide
# prabhupant                                     0  ...                                                0
# jwasham                                        0  ...                                                0
# spring-projects                                0  ...                                                0
# P1xt                                           0  ...                                                0
# hussien89aa                                    0  ...                                                0
# microsoft                                      0  ...                                                0
# jmportilla                                     0  ...                                                0
# Azure                                          0  ...                                                0
# bufferapp                                      0  ...                                                0
# apple                                          0  ...                                                0
# VastoLorde95                                   0  ...                                                0
# vmironichev                                    0  ...                                                0
# spring-cloud                                   0  ...                                                0
# azl397985856                                   1  ...                                                0
# vprusso                                        0  ...                                                0
# springfox                                      0  ...                                                0
# labnol                                         0  ...                                                0
# nicolashery                                    0  ...                                                0
# halo-dev                                       0  ...                                                0
# checkcheckzz                                   0  ...                                                1
# iiitv                                          0  ...                                                0
# xolstice                                       0  ...                                                0
# protocolbuffers                                0  ...                                                0
#
# [23 rows x 3055 columns]

# %%
# Add myself to this dataframe to find similarity between me and other users

# %%
my_repo_comp = []
for i in df.columns:
    if i in my_starred_repos:
        my_repo_comp.append(1)
    else:
        my_repo_comp.append(0)

# %%
mrc = pd.Series(my_repo_comp).to_frame(myun).T
mrc
# Out:
#                       0     1     2     3     ...  3051  3052  3053  3054
# hienminhnguyen717171     0     0     0     0  ...     0     0     0     0
#
# [1 rows x 3055 columns]

# %%
mrc.columns = df.columns

# %%
fdf = pd.concat([df, mrc])
fdf
# Out:
#                       https://github.com/bfirsh/jsnes  ...  https://github.com/databricks/scala-style-guide
# prabhupant                                          0  ...                                                0
# jwasham                                             0  ...                                                0
# spring-projects                                     0  ...                                                0
# P1xt                                                0  ...                                                0
# hussien89aa                                         0  ...                                                0
# microsoft                                           0  ...                                                0
# jmportilla                                          0  ...                                                0
# Azure                                               0  ...                                                0
# bufferapp                                           0  ...                                                0
# apple                                               0  ...                                                0
# VastoLorde95                                        0  ...                                                0
# vmironichev                                         0  ...                                                0
# spring-cloud                                        0  ...                                                0
# azl397985856                                        1  ...                                                0
# vprusso                                             0  ...                                                0
# springfox                                           0  ...                                                0
# labnol                                              0  ...                                                0
# nicolashery                                         0  ...                                                0
# halo-dev                                            0  ...                                                0
# checkcheckzz                                        0  ...                                                1
# iiitv                                               0  ...                                                0
# xolstice                                            0  ...                                                0
# protocolbuffers                                     0  ...                                                0
# hienminhnguyen717171                                0  ...                                                0
#
# [24 rows x 3055 columns]

# %%
l2 = my_starred_repos

# %%
l1 = fdf.iloc[-1,:][fdf.iloc[-1,:]==1].index.values

# %%
a = set(l1)
b = set(l2)

# %%
b.difference(a)
# Out:
# {'https://github.com/Azure/azure-cli',
#  'https://github.com/Azure/azure-powershell',
#  'https://github.com/P1xt/google-interview-university',
#  'https://github.com/VastoLorde95/Competitive-Programming',
#  'https://github.com/apple/swift-protobuf',
#  'https://github.com/azl397985856/leetcode',
#  'https://github.com/bufferapp/README',
#  'https://github.com/halo-dev/halo',
#  'https://github.com/hussien89aa/DataStructureAndAlgorithms',
#  'https://github.com/iiitv/algos',
#  'https://github.com/jmportilla/Python-for-Algorithms--Data-Structures--and-Interviews',
#  'https://github.com/microsoft/azure-spring-boot',
#  'https://github.com/nicolashery/mac-dev-setup',
#  'https://github.com/spring-cloud/spring-cloud-netflix',
#  'https://github.com/springfox/springfox',
#  'https://github.com/vmironichev/phone-app',
#  'https://github.com/xolstice/protobuf-maven-plugin'}

# %%
from sklearn.metrics import jaccard_similarity_score
from scipy.stats import pearsonr

# %%
sim_score = {}
for i in range(len(fdf)):
    ss = pearsonr(fdf.iloc[-1,:], fdf.iloc[i,:])
    sim_score.update({i: ss[0]})
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:3508: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
sf = pd.Series(sim_score).to_frame('similarity')
sf
# Out:
#     similarity
# 0     0.092767
# 1     0.033519
# 2          NaN
# 3    -0.004174
# 4    -0.001502
# 5          NaN
# 6    -0.001227
# 7          NaN
# 8          NaN
# 9          NaN
# 10   -0.004353
# 11   -0.002456
# 12         NaN
# 13   -0.030039
# 14    0.030128
# 15         NaN
# 16   -0.008589
# 17   -0.002297
# 18         NaN
# 19    0.016323
# 20         NaN
# 21         NaN
# 22         NaN
# 23    1.000000

# %%
sf.sort_values('similarity', ascending= False)
# Out:
#     similarity
# 23    1.000000
# 0     0.092767
# 1     0.033519
# 14    0.030128
# 19    0.016323
# 6    -0.001227
# 4    -0.001502
# 17   -0.002297
# 11   -0.002456
# 3    -0.004174
# 10   -0.004353
# 16   -0.008589
# 13   -0.030039
# 2          NaN
# 5          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 12         NaN
# 15         NaN
# 18         NaN
# 20         NaN
# 21         NaN
# 22         NaN

# %%
fdf.index[5]
# Out:
# 'microsoft'

# %%
fdf.iloc[71,:][fdf.iloc[71,:]==1]

# %%
all_recs[(all_recs==1).all(axis=1)]

# %%
all_recs = fdf.iloc[[31,5,71,79],:][fdf.iloc[[31,5,71,79],:]==1].fillna(0).T

# %%
str_recs_tmp = all_recs[all_recs[myun]==0].copy()
str_recs = str_recs_tmp.iloc[:,:-1].copy()
str_recs

# %%
str_recs[(str_recs==1).all(axis=1)]

# %%
str_recs[str_recs.sum(axis=1)>1]
